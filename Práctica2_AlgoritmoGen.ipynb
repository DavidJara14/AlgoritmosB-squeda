# %% [markdown]
# <a href="https://colab.research.google.com/github/DavidJara14/AlgoritmosB-squeda/blob/main/Pr%C3%A1ctica2_AlgoritmoGen.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Algoritmos Genéticos
#
# ##Parte 3: Algoritmos genéticos para optimización de rutas de metro
# ###Descripción del problema:
# Se desea encontrar la mejor combinación de estaciones para optimizar una ruta turística en metro, maximizando la cantidad de sitios visitados en un tiempo determinado.
#
# ###Tareas:
# 1. Representar una ruta en metro como un cromosoma (lista de estaciones en un orden
# determinado).
# 2. Definir una función de aptitud basada en el tiempo de viaje y la cantidad de sitios
# visitados.
# 3. Implementar un algoritmo genético con selección, cruza y mutación para encontrar
# la mejor ruta.
# 4. Probar el algoritmo con un conjunto de 10 estaciones y analizar los resultados.

# %% [markdown]
# - Primero creamos el dataseed del grafo metro:
#   1. El diccionario **dicctionaryValuesNode** tendrá como llave el nombre la estación y el contenido será la cantidad de sitios turísticos visitados.
#   2. El diccionario **dictionaryConexionStations** tendrá como llave el nombre la estación y el contenido serán listas compuesas de un string y un int, el string corresponde al nombre de la estación con la que está conectado y el int el costo de camino por moverse a esta estación, el cuál consideramos como un tiempo en minutos.
#
# - También establecemos un modelo integrado por 10 estaciones, vamos a considerar que la conexión entre estaciones debe ser inmediata, por lo que la estación en la posición [0] del arreglo debe tener conexión inmediata con la estación en la posición [1] y así sucesivamente.
#
# - Se fijará un tiempo máximo de viaje en función de la cantidad de estaciones del individuo

# %%
import random

#modelo = ["Bellas_artes","Garibaldi","Guerrero","Hidalgo","Balderas"] #Objetivo
modelo = ["Bellas_artes","Garibaldi","Guerrero","Hidalgo","Balderas","Salto_del_agua","Pino_suarez","Candelaria","Morelos","San_Lazaro"] #Objetivo

largo = 10 #La longitud del material genetico de cada individuo, o cantidad de estaciones recorridas
num = 20 #La cantidad de individuos que habra en la poblacion
pressure = 4 #Cuantos individuos se seleccionan para reproduccion. Necesariamente mayor que 2
mutation_chance = 0.4 #La probabilidad de que un individuo mute
max_time_viaje = largo * 4 #minutos

#Key -> Nombre de la estacion : Value -> Cantidad de sitios visitados
dicctionaryValuesNode = {
  "Pantitlan":0,
  "El_rosario":1,
  "Instituto_del_petroleo":6,
  "Deportivo_18_de_Marzo":6,
  "La_Raza":6,
  "Martin_Carrera":5,
  "Consulado":4,
  "Tacuba":10,
  "Oceania":2,
  "Guerrero":10,
  "Garibaldi":10,
  "Hidalgo":10,
  "Bellas_artes":10,
  "Morelos":5,
  "San_Lazaro":5,
  "Balderas":8,
  "Salto_del_agua":7,
  "Pino_suarez":6,
  "Candelaria":5,
  "Tacubaya":10,
  "CentroMedico":7,
  "Chabacano":5,
  "Jamaica":4,
  "Santa_Anita":4,
  "Mixcoac":1,
  "Zapata":7,
  "Ermita":6,
  "Atlalilco":6,
  "Universidad":1,
  "La_Villa_Basilica":1
}

#Key -> Nombre de la estacion : Value -> ["Estacion Transborde", costo por moverse a esa estacion]
dictionaryConexionStations = {
  "Pantitlan":[["Oceania",6],["San_Lazaro",12],["Jamaica",10]],
  "El_rosario":[["Tacuba",6],["Instituto_del_petroleo",12]],
  "Instituto_del_petroleo":[["El_rosario",12],["La_Raza",4],["Deportivo_18_de_Marzo",4]],
  "Deportivo_18_de_Marzo":[["Instituto_del_petroleo",4],["La_Raza",4],["La_Villa_Basilica",2]],
  "La_Raza":[["Instituto_del_petroleo",4],["Deportivo_18_de_Marzo",4],["Consulado",6],["Guerrero",4]],
  "Martin_Carrera":[["La_Villa_Basilica",2],["Consulado",6]],
  "Consulado":[["Martin_Carrera",6],["La_Raza",6],["Morelos",4],["Oceania",6]],
  "Tacuba":[["El_rosario",6],["Tacubaya",10],["Hidalgo",14]],
  "Oceania":[["Consulado",6],["San_Lazaro",6],["Pantitlan",6]],
  "Guerrero":[["La_Raza",4],["Garibaldi",2],["Hidalgo",2]],
  "Garibaldi":[["Guerrero",2],["Bellas_artes",2],["Morelos",6]],
  "Hidalgo":[["Guerrero",2],["Bellas_artes",2],["Balderas",4],["Tacuba",14]],
  "Bellas_artes":[["Garibaldi",2],["Hidalgo",2],["Salto_del_agua",4],["Pino_suarez",6]],
  "Morelos":[["Consulado",4],["Garibaldi",6],["Candelaria",2],["San_Lazaro",2]],
  "San_Lazaro":[["Morelos",2],["Candelaria",2],["Pantitlan",12],["Oceania",6]],
  "Balderas":[["Hidalgo",4],["Tacubaya",12],["CentroMedico",6],["Salto_del_agua",2]],
  "Salto_del_agua":[["Bellas_artes",4],["Balderas",2],["Chabacano",6],["Pino_suarez",4]],
  "Pino_suarez":[["Bellas_artes",6],["Salto_del_agua",4],["Chabacano",4],["Candelaria",4]],
  "Candelaria":[["Morelos",2],["Pino_suarez",4],["Jamaica",4],["San_Lazaro",2]],
  "Tacubaya":[["Tacuba",10],["Mixcoac",6],["CentroMedico",6],["Balderas",12]],
  "CentroMedico":[["Balderas",6],["Tacubaya",6],["Zapata",8],["Chabacano",4]],
  "Chabacano":[["Pino_suarez",4],["Salto_del_agua",6],["CentroMedico",4],["Ermita",12],["Santa_Anita",4],["Jamaica",2]],
  "Jamaica":[["Candelaria",4],["Chabacano",2],["Santa_Anita",2],["Pantitlan",10]],
  "Santa_Anita":[["Jamaica",2],["Chabacano",4],["Atlalilco",12]],
  "Mixcoac":[["Tacubaya",6],["Zapata",6]],
  "Zapata":[["CentroMedico",8],["Mixcoac",6],["Universidad",10],["Ermita",6]],
  "Ermita":[["Zapata",6],["Chabacano",12],["Atlalilco",4]],
  "Atlalilco":[["Ermita",4],["Santa_Anita",12]],
  "Universidad":[["Zapata",10]],
  "La_Villa_Basilica":[["Deportivo_18_de_Marzo",2],["Martin_Carrera",2]]
}

# %% [markdown]
# ##Antes de continuar con el algoritmo vamos a crear un grafo con el dataseed que establecimos para visualizar de manera clara la estructura del árbol:

# %%
# Creamos un grafo para visualizar la dataseed
import networkx as nx
import matplotlib.pyplot as plt

def crear_grafo_metro(dictionaryConexionStations, dicctionaryValuesNode):
  grafo = nx.Graph()

  for estacion, sitios_visitados in dicctionaryValuesNode.items():
    grafo.add_node(estacion, sitios_visitados=sitios_visitados)

  for estacion, conexiones in dictionaryConexionStations.items():
    for conexion in conexiones:
      estacion_destino, costo = conexion
      grafo.add_edge(estacion, estacion_destino, costo=costo)

  return grafo

grafo_metro = crear_grafo_metro(dictionaryConexionStations, dicctionaryValuesNode)
fig = plt.figure(figsize=(16, 8))
ax = fig.add_subplot(111)
pos = nx.spring_layout(grafo_metro)
labels_aristas = nx.get_edge_attributes(grafo_metro, 'costo')
labels_nodos = {nodo: f"{nodo}\n({grafo_metro.nodes[nodo]['sitios_visitados']})" for nodo in grafo_metro.nodes}

nx.draw(grafo_metro, with_labels=False, node_color='lightblue', node_size=1000, pos=pos, ax=ax)
nx.draw_networkx_labels(grafo_metro, pos, labels=labels_nodos, font_size=10)
nx.draw_networkx_edge_labels(grafo_metro, pos, edge_labels=labels_aristas, font_size=8)

plt.show()

# %% [markdown]
# ##Se crea la función individual, la cuál devolverá una lista de estaciones de manera alreatoria, la única restricción es que no pueden repetirse estaciones dentro del individuo, el tamaño del arreglo está dado por el valor de **largo** (que corresponde con la cantidad de metrial genético de cada individuo), para esta prueba se estableció un material genético de **10** estaciones

# %%
def individual():
    """
        Crea un individuo compuesto por una lista de
        estaciones de metro no repetidas
    """
    individuo = []
    while len(individuo) < largo:
      estacion = random.choice(list(dicctionaryValuesNode.keys()))
      if estacion not in individuo:
        individuo.append(estacion)

    return individuo

# %% [markdown]
# ###A continuación probamos la función **individual()** creando 10 individuos, cómo se puede observar cada individuo tiene 10 estaciones diferentes que no necesariemente tienen conexión directa entre ellas

# %%
# Test de la funcion individual
for i in range(10):
  individuo = individual()
  print(individuo)
# Out:
# ['Balderas', 'Oceania', 'Hidalgo', 'El_rosario', 'Candelaria', 'Pino_suarez', 'Zapata', 'Salto_del_agua', 'Universidad', 'Instituto_del_petroleo']
# ['Balderas', 'Guerrero', 'Martin_Carrera', 'Consulado', 'Mixcoac', 'Universidad', 'San_Lazaro', 'La_Villa_Basilica', 'Zapata', 'Garibaldi']
# ['Santa_Anita', 'La_Villa_Basilica', 'Bellas_artes', 'Zapata', 'Tacubaya', 'Guerrero', 'El_rosario', 'Universidad', 'Chabacano', 'Consulado']
# ['Salto_del_agua', 'Bellas_artes', 'La_Raza', 'Consulado', 'Instituto_del_petroleo', 'Mixcoac', 'Universidad', 'Morelos', 'Martin_Carrera', 'San_Lazaro']
# ['Consulado', 'CentroMedico', 'Bellas_artes', 'La_Villa_Basilica', 'Morelos', 'Guerrero', 'Martin_Carrera', 'Jamaica', 'Pantitlan', 'El_rosario']
# ['Morelos', 'Hidalgo', 'Jamaica', 'Pantitlan', 'La_Raza', 'Pino_suarez', 'CentroMedico', 'Ermita', 'La_Villa_Basilica', 'Martin_Carrera']
# ['Morelos', 'Atlalilco', 'Hidalgo', 'CentroMedico', 'Bellas_artes', 'Santa_Anita', 'Zapata', 'La_Villa_Basilica', 'Deportivo_18_de_Marzo', 'Chabacano']
# ['Candelaria', 'Deportivo_18_de_Marzo', 'Morelos', 'El_rosario', 'Salto_del_agua', 'Pino_suarez', 'San_Lazaro', 'La_Villa_Basilica', 'Consulado', 'Atlalilco']
# ['Universidad', 'Deportivo_18_de_Marzo', 'Oceania', 'Atlalilco', 'CentroMedico', 'Guerrero', 'La_Raza', 'Santa_Anita', 'Martin_Carrera', 'Mixcoac']
# ['Salto_del_agua', 'Hidalgo', 'Jamaica', 'Oceania', 'Martin_Carrera', 'Deportivo_18_de_Marzo', 'Universidad', 'Tacubaya', 'Ermita', 'Tacuba']

# %% [markdown]
# ##Ahora creamos la función **crearPoblacion()** la cuál devuelve un arreglo de individuos creados con la función individual. La longitud de esta arreglo (tamaño de la población) está dada por la variable **num**, para este caso definimos una población de 20

# %%
def crearPoblacion():
    """
        Crea una poblacion nueva de individuos
    """
    return [individual() for i in range(num)]

# %% [markdown]
# ##Definimos la función **obtener_tiempo_viaje()** encargada de regresar el tiempo de viaje entre dos estaciones, regresa el valor asociado al costo de camino entre dos estaciones, si no existe conexión definida, supondremos un costo *infinito* que se penalizará después, si las dos estaciones dadas son la misma, entonces el costo es de 0, puesto que no debe trasladarse

# %%
# Función para obtener el tiempo de viaje entre dos estaciones
def obtener_tiempo_viaje(estacion1, estacion2):
  """
      Regresa el costo entre moverse de una estación a otra
  """
  if(estacion1 == estacion2): # Si te mueves a la misma estación
    return 0

  if estacion1 in dictionaryConexionStations:
    for conexion in dictionaryConexionStations[estacion1]:
      if conexion[0] == estacion2:
        return conexion[1]

  return float("inf") #Si no existe conexión declarada, entonces se supone un costo "infinito"

# %% [markdown]
# ### Probamos la función crearPoblacion() y la función obtener_tiempo_viaje()

# %%
# Creamos una poblacion
miPoblacion = crearPoblacion()
#Test funcion "obtener_tiempo_viaje"
unIndividuo = miPoblacion[0] # Guardamos en una variable la información de un indiviudo de la población
tiempo_total_viaje = 0
print(unIndividuo)
for i in range(len(unIndividuo)-1): # Para el individuo almacenado calculamos el tiempo de viaje entre cada una de las estaciones
  tiempo_viaje = obtener_tiempo_viaje(unIndividuo[i],unIndividuo[i+1])
  tiempo_total_viaje += tiempo_viaje
  print(f"Tiempo entre la estacion {unIndividuo[i]} y {unIndividuo[i+1]} {tiempo_viaje}")
print(f"Tiempo total de viaje: {tiempo_total_viaje}")
# Out:
# ['Consulado', 'Ermita', 'Atlalilco', 'Salto_del_agua', 'Oceania', 'Santa_Anita', 'Hidalgo', 'San_Lazaro', 'Bellas_artes', 'El_rosario']
# Tiempo entre la estacion Consulado y Ermita inf
# Tiempo entre la estacion Ermita y Atlalilco 4
# Tiempo entre la estacion Atlalilco y Salto_del_agua inf
# Tiempo entre la estacion Salto_del_agua y Oceania inf
# Tiempo entre la estacion Oceania y Santa_Anita inf
# Tiempo entre la estacion Santa_Anita y Hidalgo inf
# Tiempo entre la estacion Hidalgo y San_Lazaro inf
# Tiempo entre la estacion San_Lazaro y Bellas_artes inf
# Tiempo entre la estacion Bellas_artes y El_rosario inf
# Tiempo total de viaje: inf

# %%
"""
  Recibe un individuo y retorna True si el individuo tiene
  estaciones repetidas, False en caso contrario
"""
def check_duplicidad(individuo):
  if(len(set(individuo)) < largo):
    return True
  else:
    return False

# %% [markdown]
# ## La función **verificar_y_reordenar_individuo()** nos ayudará para mostrar apropiadamente (en un orden de conexiones correcto) el individuo final

# %%
def verificar_y_reordenar_individuo(individuo, diccionario_conexiones):
  """
  Recibe un array de estaciones y verifica si cada estación está conectada
  con la siguiente.

  Si el orden original es correcto, retorna (True, individuo).
  Si no lo es, intenta reordenar la lista
  """
  def es_valido(array_estaciones):
    for i in range(len(array_estaciones) - 1):
      estacion_actual = array_estaciones[i]
      estacion_siguiente = array_estaciones[i + 1]

      if estacion_actual == estacion_siguiente: # Si ambas estaciones son iguales diremos que están conectadas.
        continue

      conexiones = diccionario_conexiones.get(estacion_actual, [])# Obtenemos la lista de conexiones de la estación actual
      conexion_encontrada = False
      for conexion in conexiones:
        if conexion[0] == estacion_siguiente: # Si se encontro conexion inmediatamente
          conexion_encontrada = True
          break  # Salimos del ciclo ya que se encontro conexion

      if not conexion_encontrada:# El orden no es correcto, regresa False
        return False

    return True # El orden es válido, regresa True

  def buscar_orden_valido(array_ordenado, array_desordenado):
    if not array_desordenado:# Si ya no hay estaciones por ordenar
      if es_valido(array_ordenado): # Si array ordenado es correcto, lo regresamos
        return array_ordenado
      else:
        return None

    for i in range(len(array_desordenado)):
      estacion = array_desordenado[i]

      if not array_ordenado:
        nueva_ruta = buscar_orden_valido([estacion], array_desordenado[:i] + array_desordenado[i+1:])
        if nueva_ruta != None:
          return nueva_ruta
      else:
        # Verificamos si la última estación en la ruta tiene conexión con la estación actual
        conexiones = diccionario_conexiones.get(array_ordenado[-1], [])
        if any(conexion[0] == estacion for conexion in conexiones):
          nueva_ruta = buscar_orden_valido(array_ordenado + [estacion], array_desordenado[:i] + array_desordenado[i+1:])
          if nueva_ruta is not None:
            return nueva_ruta

    return None # Si ninguna opción genera un orden válido, retornamos None


  # Antes que nada verficamos si el orden original del individuo es válido.
  if es_valido(individuo):
    return True, individuo

  # Si no, intentamos reordenar todo el individuo.
  nuevo_individuo = buscar_orden_valido([], individuo)
  if nuevo_individuo != None:
    return True, nuevo_individuo
  else:
    return False, individuo

# %% [markdown]
# ## La función **calcularFitness()** regresará una ponderación de rendimiento **fitness**, **tiempo total de viaje** y **número de sitios visitados**. La ponderación depende de:
# - Tiempo total de viaje entre estaciones
# - Sitios visitados en total
# - Si el tiempo total no excede el máximo establecido
# - Que tan parecido es el individuo con el modelo establecido al inicio

# %%
def calcularFitness(individual):
  """
      Calcula el fitness de un individuo
  """
  tiempo_total = 0
  sitios_visitados = 0
  fitness = 1
  estaciones_visitadas = []

  for i in range(len(individual)): #Si el individuo se parece al modelo aumenta el fitness
    if individual[i] == modelo[i]:
      fitness *= 1.15
  #print(f"Fitness despues de comparar con modelo {fitness}")

  #Calculamos el fitness en funcion del tiempo de viaje y sitios visitados
  for i in range(len(individual)-1):
    tiempoViaje = obtener_tiempo_viaje(individual[i],individual[i+1])
    #print(f"Tiempo entre la estacion {individual[i]} y {individual[i+1]} {tiempoViaje}")
    if tiempoViaje == float("inf"): #En caso de que no exista conexion directa entre estaciones, se penaliza con un tiempo 25 minutos
      tiempoViaje = 25
    tiempo_total += tiempoViaje
    #print(f"Tiempo total de viaje in for: {tiempo_total}")

  for estacion in individual:
    if estacion not in estaciones_visitadas: #Si la estación aún no ha sido visitada, agregamos la cantidad de sitios visitados
      sitios_visitados += dicctionaryValuesNode.get(estacion,0) #Se obtienen los sitios visitados en total para cada individuo
      estaciones_visitadas.append(estacion)

  fitness *= sitios_visitados*0.8
  #print(f"Fitness despues de sitios vistados {fitness}")

  fitness -= tiempo_total*0.1
  #print(f"Fitness despues de tiempo total {fitness}")

  #Penalizaciones
  if(tiempo_total > max_time_viaje): #Si el tiempo total de viaje ha superado el tiempo maximo establecido, se penaliza el fitness
    fitness *= 0.75
  #print(f"Fitness despues de evaluar max time viaje {fitness}")

  if check_duplicidad(individual): #Si el individuo tiene estaciones repetidas disminuye el fitness
    fitness = fitness / 2

  #print(f"Fitness despues de ver repetidos {fitness}")

  return round(fitness,3), tiempo_total, sitios_visitados

# %%
"""
  Recibe una población y regresa el promedio de fitness de todos los
  individuos de la población
"""
def averageFitnessPoblacion(poblacion):
  averageFitness_poblacion = 0
  for i in range(len(poblacion)):
    averageFitness_poblacion += calcularFitness(poblacion[i])[0]

  #print(averageFitness_poblacion)
  #print(len(poblacion))
  return averageFitness_poblacion / len(poblacion)

# %%
#Test de la fución calcularFitness()
for individuo in miPoblacion:
  print(f"Fit: {calcularFitness(individuo)[0]} \tIndividuo: {individuo}")
# Out:
# Fit: 17.7 	Individuo: ['Consulado', 'Ermita', 'Atlalilco', 'Salto_del_agua', 'Oceania', 'Santa_Anita', 'Hidalgo', 'San_Lazaro', 'Bellas_artes', 'El_rosario']
# Fit: 14.85 	Individuo: ['Garibaldi', 'La_Raza', 'CentroMedico', 'Salto_del_agua', 'Jamaica', 'Santa_Anita', 'Deportivo_18_de_Marzo', 'San_Lazaro', 'Mixcoac', 'Pantitlan']
# Fit: 17.85 	Individuo: ['Martin_Carrera', 'Zapata', 'Jamaica', 'Candelaria', 'Pino_suarez', 'Mixcoac', 'Chabacano', 'Ermita', 'Tacuba', 'Oceania']
# Fit: 15.945 	Individuo: ['Universidad', 'Garibaldi', 'Morelos', 'Atlalilco', 'El_rosario', 'Martin_Carrera', 'Santa_Anita', 'Jamaica', 'Ermita', 'Mixcoac']
# Fit: 7.965 	Individuo: ['Salto_del_agua', 'Ermita', 'Universidad', 'Consulado', 'El_rosario', 'La_Villa_Basilica', 'Tacuba', 'Pantitlan', 'Morelos', 'Mixcoac']
# Fit: 9.525 	Individuo: ['CentroMedico', 'Candelaria', 'Mixcoac', 'Universidad', 'Ermita', 'Oceania', 'Chabacano', 'Martin_Carrera', 'Balderas', 'Jamaica']
# Fit: 19.5 	Individuo: ['Tacubaya', 'Oceania', 'Universidad', 'Garibaldi', 'Consulado', 'Candelaria', 'Deportivo_18_de_Marzo', 'La_Raza', 'Jamaica', 'Hidalgo']
# Fit: 18.45 	Individuo: ['Instituto_del_petroleo', 'Tacuba', 'Tacubaya', 'Atlalilco', 'Consulado', 'Santa_Anita', 'Oceania', 'Chabacano', 'Martin_Carrera', 'Candelaria']
# Fit: 20.85 	Individuo: ['Candelaria', 'Deportivo_18_de_Marzo', 'Jamaica', 'Tacubaya', 'Oceania', 'Santa_Anita', 'Garibaldi', 'Bellas_artes', 'La_Villa_Basilica', 'Balderas']
# Fit: 9.975 	Individuo: ['Salto_del_agua', 'Pantitlan', 'La_Raza', 'Consulado', 'Martin_Carrera', 'Universidad', 'Santa_Anita', 'Oceania', 'Candelaria', 'Atlalilco']
# Fit: 28.86 	Individuo: ['Tacuba', 'Ermita', 'Morelos', 'Zapata', 'Oceania', 'Salto_del_agua', 'Candelaria', 'Garibaldi', 'La_Raza', 'Instituto_del_petroleo']
# Fit: 15.15 	Individuo: ['Universidad', 'Deportivo_18_de_Marzo', 'Hidalgo', 'Zapata', 'Ermita', 'Oceania', 'Instituto_del_petroleo', 'La_Villa_Basilica', 'Salto_del_agua', 'Candelaria']
# Fit: 16.125 	Individuo: ['Mixcoac', 'Balderas', 'Atlalilco', 'La_Raza', 'Chabacano', 'Universidad', 'El_rosario', 'Tacubaya', 'Guerrero', 'Zapata']
# Fit: 20.475 	Individuo: ['Balderas', 'Universidad', 'La_Villa_Basilica', 'San_Lazaro', 'Oceania', 'Bellas_artes', 'Chabacano', 'Tacubaya', 'Tacuba', 'Ermita']
# Fit: 15.3 	Individuo: ['Universidad', 'Ermita', 'Salto_del_agua', 'La_Raza', 'Deportivo_18_de_Marzo', 'San_Lazaro', 'Bellas_artes', 'La_Villa_Basilica', 'Santa_Anita', 'Morelos']
# Fit: 23.325 	Individuo: ['Ermita', 'La_Raza', 'Bellas_artes', 'Morelos', 'CentroMedico', 'Tacuba', 'Martin_Carrera', 'Deportivo_18_de_Marzo', 'Hidalgo', 'Oceania']
# Fit: 9.975 	Individuo: ['Jamaica', 'Balderas', 'San_Lazaro', 'La_Raza', 'Consulado', 'Oceania', 'Santa_Anita', 'Pantitlan', 'La_Villa_Basilica', 'Ermita']
# Fit: 26.685 	Individuo: ['Tacuba', 'Consulado', 'Ermita', 'Deportivo_18_de_Marzo', 'Pantitlan', 'Oceania', 'Guerrero', 'Candelaria', 'Bellas_artes', 'Pino_suarez']
# Fit: 21.45 	Individuo: ['Atlalilco', 'Tacubaya', 'Salto_del_agua', 'La_Villa_Basilica', 'Garibaldi', 'Pantitlan', 'Candelaria', 'San_Lazaro', 'Bellas_artes', 'Zapata']
# Fit: 15.45 	Individuo: ['Guerrero', 'Santa_Anita', 'Jamaica', 'San_Lazaro', 'Garibaldi', 'Pino_suarez', 'Oceania', 'Chabacano', 'El_rosario', 'Consulado']

# %%
#Test de la función averageFitnessPoblacion()
averageFitnessPoblacion(miPoblacion)
# Out:
# 17.27025

# %% [markdown]
# ## Se declara la función **selection_and_reproduction()** encargada de calcular el fitness para cada individuo y ordenarlo de acurdo a su puntaje, para posteriormente mezaclar el material genético de los individuos mejor puntuados, devuelve el nuevo arrglo de individuos

# %%
def selection_and_reproduction(population):
    """
        Puntua todos los elementos de la poblacion (population) y se queda con los mejores
        guardandolos dentro de 'selected'.
        Despues mezcla el material genetico de los elegidos para crear nuevos individuos y
        llenar la poblacion.
    """
    puntuados = [ (calcularFitness(i)[0], i) for i in population] #Calcula el fitness de cada individuo, y lo guarda en pares ordenados de la forma (fitness , ["estacion","estacion","estacion"])
    puntuados = [i[1] for i in sorted(puntuados)] #Ordena los pares ordenados y se queda solo con el array de valores

    population = puntuados
    selected =  puntuados[(len(puntuados)-pressure):] #Esta linea selecciona los 'n' individuos del final, donde n viene dado por 'pressure'

    #Se mezcla el material genetico para crear nuevos individuos
    for i in range(len(population)-pressure):
      punto = random.randint(1,largo-1) #Se elige un punto para hacer el intercambio
      padre = random.sample(selected, 2) #Se eligen dos padres

      population[i][:punto] = padre[0][:punto] #Se mezcla el material genetico de los padres en cada nuevo individuo
      population[i][punto:] = padre[1][punto:]

      #print(f"Individuo creado tras reproduccion: {population[i]}")

    return population #El array 'population' tiene ahora una nueva poblacion de individuos, que se devuelven

# %%
#Test selection_and_reproduction()
other_poblacion = crearPoblacion()
for i in range(5):
  print(selection_and_reproduction(other_poblacion))
# Out:
# [['Bellas_artes', 'Morelos', 'Deportivo_18_de_Marzo', 'Balderas', 'Ermita', 'Tacubaya', 'Salto_del_agua', 'Morelos', 'Instituto_del_petroleo', 'Ermita'], ['Ermita', 'Tacuba', 'Zapata', 'Hidalgo', 'Balderas', 'Tacubaya', 'Tacuba', 'Deportivo_18_de_Marzo', 'Martin_Carrera', 'Bellas_artes'], ['Pino_suarez', 'San_Lazaro', 'Deportivo_18_de_Marzo', 'Guerrero', 'Hidalgo', 'Consulado', 'Balderas', 'Deportivo_18_de_Marzo', 'Guerrero', 'El_rosario'], ['La_Raza', 'Atlalilco', 'San_Lazaro', 'Hidalgo', 'CentroMedico', 'Consulado', 'Balderas', 'Deportivo_18_de_Marzo', 'Guerrero', 'El_rosario'], ['La_Raza', 'Atlalilco', 'San_Lazaro', 'Pino_suarez', 'Balderas', 'Tacubaya', 'Tacuba', 'Deportivo_18_de_Marzo', 'El_rosario', 'Oceania'], ['La_Raza', 'Atlalilco', 'Zapata', 'Hidalgo', 'CentroMedico', 'Consulado', 'Balderas', 'Deportivo_18_de_Marzo', 'Guerrero', 'El_rosario'], ['Pino_suarez', 'San_Lazaro', 'Deportivo_18_de_Marzo', 'Guerrero', 'Balderas', 'Tacubaya', 'Tacuba', 'Deportivo_18_de_Marzo', 'Martin_Carrera', 'Bellas_artes'], ['Ermita', 'Tacuba', 'Zapata', 'Hidalgo', 'Hidalgo', 'Santa_Anita', 'Candelaria', 'Morelos', 'Instituto_del_petroleo', 'Ermita'], ['Ermita', 'Tacuba', 'Zapata', 'Hidalgo', 'CentroMedico', 'Consulado', 'Balderas', 'Deportivo_18_de_Marzo', 'Martin_Carrera', 'Bellas_artes'], ['Ermita', 'Tacuba', 'Zapata', 'Hidalgo', 'CentroMedico', 'Consulado', 'Salto_del_agua', 'Consulado', 'El_rosario', 'Oceania'], ['La_Raza', 'Atlalilco', 'San_Lazaro', 'Guerrero', 'Hidalgo', 'Santa_Anita', 'Candelaria', 'Morelos', 'Instituto_del_petroleo', 'Ermita'], ['Pino_suarez', 'San_Lazaro', 'Deportivo_18_de_Marzo', 'Guerrero', 'Hidalgo', 'Santa_Anita', 'Tacuba', 'Deportivo_18_de_Marzo', 'Martin_Carrera', 'Bellas_artes'], ['Pino_suarez', 'San_Lazaro', 'Deportivo_18_de_Marzo', 'Guerrero', 'Hidalgo', 'Santa_Anita', 'Salto_del_agua', 'Consulado', 'El_rosario', 'Oceania'], ['Pino_suarez', 'San_Lazaro', 'Deportivo_18_de_Marzo', 'Balderas', 'Ermita', 'Tacubaya', 'Salto_del_agua', 'Consulado', 'El_rosario', 'Oceania'], ['La_Raza', 'Atlalilco', 'San_Lazaro', 'Pino_suarez', 'Balderas', 'Tacubaya', 'Tacuba', 'Deportivo_18_de_Marzo', 'Martin_Carrera', 'Oceania'], ['La_Raza', 'Atlalilco', 'San_Lazaro', 'Pino_suarez', 'Balderas', 'Santa_Anita', 'Candelaria', 'Morelos', 'Instituto_del_petroleo', 'Ermita'], ['Bellas_artes', 'Morelos', 'Deportivo_18_de_Marzo', 'Balderas', 'Ermita', 'Tacubaya', 'Salto_del_agua', 'Consulado', 'El_rosario', 'Oceania'], ['Pino_suarez', 'San_Lazaro', 'Deportivo_18_de_Marzo', 'Guerrero', 'Hidalgo', 'Santa_Anita', 'Candelaria', 'Morelos', 'Instituto_del_petroleo', 'Ermita'], ['Ermita', 'Tacuba', 'Zapata', 'Hidalgo', 'CentroMedico', 'Consulado', 'Balderas', 'Deportivo_18_de_Marzo', 'Guerrero', 'El_rosario'], ['La_Raza', 'Atlalilco', 'San_Lazaro', 'Pino_suarez', 'Balderas', 'Tacubaya', 'Tacuba', 'Deportivo_18_de_Marzo', 'Martin_Carrera', 'Bellas_artes']]
# [['Ermita', 'Tacuba', 'Zapata', 'Hidalgo', 'CentroMedico', 'Consulado', 'Balderas', 'Deportivo_18_de_Marzo', 'Guerrero', 'El_rosario'], ['La_Raza', 'Atlalilco', 'San_Lazaro', 'Pino_suarez', 'CentroMedico', 'Consulado', 'Balderas', 'Deportivo_18_de_Marzo', 'Guerrero', 'El_rosario'], ['La_Raza', 'Atlalilco', 'San_Lazaro', 'Pino_suarez', 'CentroMedico', 'Consulado', 'Balderas', 'Deportivo_18_de_Marzo', 'Martin_Carrera', 'Bellas_artes'], ['La_Raza', 'Atlalilco', 'San_Lazaro', 'Hidalgo', 'CentroMedico', 'Consulado', 'Balderas', 'Deportivo_18_de_Marzo', 'Martin_Carrera', 'Bellas_artes'], ['La_Raza', 'Atlalilco', 'San_Lazaro', 'Pino_suarez', 'Balderas', 'Tacubaya', 'Tacuba', 'Deportivo_18_de_Marzo', 'Martin_Carrera', 'Bellas_artes'], ['La_Raza', 'Atlalilco', 'San_Lazaro', 'Pino_suarez', 'Balderas', 'Tacubaya', 'Tacuba', 'Deportivo_18_de_Marzo', 'Guerrero', 'El_rosario'], ['La_Raza', 'Atlalilco', 'San_Lazaro', 'Pino_suarez', 'Balderas', 'Tacubaya', 'Tacuba', 'Deportivo_18_de_Marzo', 'Martin_Carrera', 'Oceania'], ['Ermita', 'Tacuba', 'San_Lazaro', 'Pino_suarez', 'Balderas', 'Tacubaya', 'Tacuba', 'Deportivo_18_de_Marzo', 'Martin_Carrera', 'Bellas_artes'], ['Ermita', 'Tacuba', 'San_Lazaro', 'Pino_suarez', 'Balderas', 'Tacubaya', 'Tacuba', 'Deportivo_18_de_Marzo', 'Martin_Carrera', 'Bellas_artes'], ['La_Raza', 'Atlalilco', 'San_Lazaro', 'Pino_suarez', 'CentroMedico', 'Consulado', 'Balderas', 'Deportivo_18_de_Marzo', 'Guerrero', 'El_rosario'], ['La_Raza', 'Atlalilco', 'Zapata', 'Hidalgo', 'CentroMedico', 'Consulado', 'Balderas', 'Deportivo_18_de_Marzo', 'Guerrero', 'El_rosario'], ['La_Raza', 'Atlalilco', 'San_Lazaro', 'Pino_suarez', 'Balderas', 'Tacubaya', 'Tacuba', 'Deportivo_18_de_Marzo', 'Martin_Carrera', 'Bellas_artes'], ['La_Raza', 'Atlalilco', 'San_Lazaro', 'Pino_suarez', 'Balderas', 'Tacubaya', 'Tacuba', 'Deportivo_18_de_Marzo', 'Martin_Carrera', 'Oceania'], ['La_Raza', 'Atlalilco', 'San_Lazaro', 'Pino_suarez', 'Balderas', 'Tacubaya', 'Tacuba', 'Deportivo_18_de_Marzo', 'Martin_Carrera', 'Oceania'], ['Ermita', 'Tacuba', 'San_Lazaro', 'Pino_suarez', 'Balderas', 'Tacubaya', 'Tacuba', 'Deportivo_18_de_Marzo', 'Martin_Carrera', 'Oceania'], ['La_Raza', 'Atlalilco', 'San_Lazaro', 'Pino_suarez', 'Balderas', 'Tacubaya', 'Tacuba', 'Deportivo_18_de_Marzo', 'Martin_Carrera', 'Bellas_artes'], ['La_Raza', 'Atlalilco', 'San_Lazaro', 'Pino_suarez', 'Balderas', 'Tacubaya', 'Tacuba', 'Deportivo_18_de_Marzo', 'Martin_Carrera', 'Oceania'], ['Ermita', 'Tacuba', 'Zapata', 'Hidalgo', 'CentroMedico', 'Consulado', 'Balderas', 'Deportivo_18_de_Marzo', 'Guerrero', 'El_rosario'], ['Ermita', 'Tacuba', 'Zapata', 'Hidalgo', 'CentroMedico', 'Consulado', 'Balderas', 'Deportivo_18_de_Marzo', 'Martin_Carrera', 'Bellas_artes'], ['La_Raza', 'Atlalilco', 'San_Lazaro', 'Pino_suarez', 'Balderas', 'Tacubaya', 'Tacuba', 'Deportivo_18_de_Marzo', 'Martin_Carrera', 'Bellas_artes']]
# [['La_Raza', 'Atlalilco', 'San_Lazaro', 'Pino_suarez', 'Balderas', 'Tacubaya', 'Tacuba', 'Deportivo_18_de_Marzo', 'Martin_Carrera', 'Bellas_artes'], ['La_Raza', 'Atlalilco', 'San_Lazaro', 'Pino_suarez', 'Balderas', 'Tacubaya', 'Tacuba', 'Deportivo_18_de_Marzo', 'Martin_Carrera', 'Bellas_artes'], ['La_Raza', 'Atlalilco', 'San_Lazaro', 'Pino_suarez', 'Balderas', 'Tacubaya', 'Tacuba', 'Deportivo_18_de_Marzo', 'Martin_Carrera', 'Bellas_artes'], ['La_Raza', 'Atlalilco', 'San_Lazaro', 'Pino_suarez', 'Balderas', 'Tacubaya', 'Tacuba', 'Deportivo_18_de_Marzo', 'Martin_Carrera', 'Bellas_artes'], ['La_Raza', 'Atlalilco', 'San_Lazaro', 'Pino_suarez', 'Balderas', 'Tacubaya', 'Tacuba', 'Deportivo_18_de_Marzo', 'Martin_Carrera', 'Bellas_artes'], ['La_Raza', 'Atlalilco', 'San_Lazaro', 'Pino_suarez', 'Balderas', 'Tacubaya', 'Tacuba', 'Deportivo_18_de_Marzo', 'Martin_Carrera', 'Bellas_artes'], ['La_Raza', 'Atlalilco', 'San_Lazaro', 'Pino_suarez', 'Balderas', 'Tacubaya', 'Tacuba', 'Deportivo_18_de_Marzo', 'Martin_Carrera', 'Bellas_artes'], ['La_Raza', 'Atlalilco', 'San_Lazaro', 'Pino_suarez', 'Balderas', 'Tacubaya', 'Tacuba', 'Deportivo_18_de_Marzo', 'Martin_Carrera', 'Bellas_artes'], ['La_Raza', 'Atlalilco', 'San_Lazaro', 'Pino_suarez', 'Balderas', 'Tacubaya', 'Tacuba', 'Deportivo_18_de_Marzo', 'Martin_Carrera', 'Bellas_artes'], ['La_Raza', 'Atlalilco', 'San_Lazaro', 'Pino_suarez', 'Balderas', 'Tacubaya', 'Tacuba', 'Deportivo_18_de_Marzo', 'Martin_Carrera', 'Bellas_artes'], ['La_Raza', 'Atlalilco', 'San_Lazaro', 'Pino_suarez', 'Balderas', 'Tacubaya', 'Tacuba', 'Deportivo_18_de_Marzo', 'Martin_Carrera', 'Bellas_artes'], ['La_Raza', 'Atlalilco', 'San_Lazaro', 'Pino_suarez', 'Balderas', 'Tacubaya', 'Tacuba', 'Deportivo_18_de_Marzo', 'Martin_Carrera', 'Bellas_artes'], ['La_Raza', 'Atlalilco', 'San_Lazaro', 'Pino_suarez', 'Balderas', 'Tacubaya', 'Tacuba', 'Deportivo_18_de_Marzo', 'Martin_Carrera', 'Bellas_artes'], ['La_Raza', 'Atlalilco', 'San_Lazaro', 'Pino_suarez', 'Balderas', 'Tacubaya', 'Tacuba', 'Deportivo_18_de_Marzo', 'Martin_Carrera', 'Bellas_artes'], ['La_Raza', 'Atlalilco', 'San_Lazaro', 'Pino_suarez', 'Balderas', 'Tacubaya', 'Tacuba', 'Deportivo_18_de_Marzo', 'Martin_Carrera', 'Bellas_artes'], ['La_Raza', 'Atlalilco', 'San_Lazaro', 'Pino_suarez', 'Balderas', 'Tacubaya', 'Tacuba', 'Deportivo_18_de_Marzo', 'Martin_Carrera', 'Bellas_artes'], ['La_Raza', 'Atlalilco', 'San_Lazaro', 'Pino_suarez', 'Balderas', 'Tacubaya', 'Tacuba', 'Deportivo_18_de_Marzo', 'Martin_Carrera', 'Bellas_artes'], ['La_Raza', 'Atlalilco', 'San_Lazaro', 'Pino_suarez', 'Balderas', 'Tacubaya', 'Tacuba', 'Deportivo_18_de_Marzo', 'Martin_Carrera', 'Bellas_artes'], ['La_Raza', 'Atlalilco', 'San_Lazaro', 'Pino_suarez', 'Balderas', 'Tacubaya', 'Tacuba', 'Deportivo_18_de_Marzo', 'Martin_Carrera', 'Bellas_artes'], ['La_Raza', 'Atlalilco', 'San_Lazaro', 'Pino_suarez', 'Balderas', 'Tacubaya', 'Tacuba', 'Deportivo_18_de_Marzo', 'Martin_Carrera', 'Bellas_artes']]
# [['La_Raza', 'Atlalilco', 'San_Lazaro', 'Pino_suarez', 'Balderas', 'Tacubaya', 'Tacuba', 'Deportivo_18_de_Marzo', 'Martin_Carrera', 'Bellas_artes'], ['La_Raza', 'Atlalilco', 'San_Lazaro', 'Pino_suarez', 'Balderas', 'Tacubaya', 'Tacuba', 'Deportivo_18_de_Marzo', 'Martin_Carrera', 'Bellas_artes'], ['La_Raza', 'Atlalilco', 'San_Lazaro', 'Pino_suarez', 'Balderas', 'Tacubaya', 'Tacuba', 'Deportivo_18_de_Marzo', 'Martin_Carrera', 'Bellas_artes'], ['La_Raza', 'Atlalilco', 'San_Lazaro', 'Pino_suarez', 'Balderas', 'Tacubaya', 'Tacuba', 'Deportivo_18_de_Marzo', 'Martin_Carrera', 'Bellas_artes'], ['La_Raza', 'Atlalilco', 'San_Lazaro', 'Pino_suarez', 'Balderas', 'Tacubaya', 'Tacuba', 'Deportivo_18_de_Marzo', 'Martin_Carrera', 'Bellas_artes'], ['La_Raza', 'Atlalilco', 'San_Lazaro', 'Pino_suarez', 'Balderas', 'Tacubaya', 'Tacuba', 'Deportivo_18_de_Marzo', 'Martin_Carrera', 'Bellas_artes'], ['La_Raza', 'Atlalilco', 'San_Lazaro', 'Pino_suarez', 'Balderas', 'Tacubaya', 'Tacuba', 'Deportivo_18_de_Marzo', 'Martin_Carrera', 'Bellas_artes'], ['La_Raza', 'Atlalilco', 'San_Lazaro', 'Pino_suarez', 'Balderas', 'Tacubaya', 'Tacuba', 'Deportivo_18_de_Marzo', 'Martin_Carrera', 'Bellas_artes'], ['La_Raza', 'Atlalilco', 'San_Lazaro', 'Pino_suarez', 'Balderas', 'Tacubaya', 'Tacuba', 'Deportivo_18_de_Marzo', 'Martin_Carrera', 'Bellas_artes'], ['La_Raza', 'Atlalilco', 'San_Lazaro', 'Pino_suarez', 'Balderas', 'Tacubaya', 'Tacuba', 'Deportivo_18_de_Marzo', 'Martin_Carrera', 'Bellas_artes'], ['La_Raza', 'Atlalilco', 'San_Lazaro', 'Pino_suarez', 'Balderas', 'Tacubaya', 'Tacuba', 'Deportivo_18_de_Marzo', 'Martin_Carrera', 'Bellas_artes'], ['La_Raza', 'Atlalilco', 'San_Lazaro', 'Pino_suarez', 'Balderas', 'Tacubaya', 'Tacuba', 'Deportivo_18_de_Marzo', 'Martin_Carrera', 'Bellas_artes'], ['La_Raza', 'Atlalilco', 'San_Lazaro', 'Pino_suarez', 'Balderas', 'Tacubaya', 'Tacuba', 'Deportivo_18_de_Marzo', 'Martin_Carrera', 'Bellas_artes'], ['La_Raza', 'Atlalilco', 'San_Lazaro', 'Pino_suarez', 'Balderas', 'Tacubaya', 'Tacuba', 'Deportivo_18_de_Marzo', 'Martin_Carrera', 'Bellas_artes'], ['La_Raza', 'Atlalilco', 'San_Lazaro', 'Pino_suarez', 'Balderas', 'Tacubaya', 'Tacuba', 'Deportivo_18_de_Marzo', 'Martin_Carrera', 'Bellas_artes'], ['La_Raza', 'Atlalilco', 'San_Lazaro', 'Pino_suarez', 'Balderas', 'Tacubaya', 'Tacuba', 'Deportivo_18_de_Marzo', 'Martin_Carrera', 'Bellas_artes'], ['La_Raza', 'Atlalilco', 'San_Lazaro', 'Pino_suarez', 'Balderas', 'Tacubaya', 'Tacuba', 'Deportivo_18_de_Marzo', 'Martin_Carrera', 'Bellas_artes'], ['La_Raza', 'Atlalilco', 'San_Lazaro', 'Pino_suarez', 'Balderas', 'Tacubaya', 'Tacuba', 'Deportivo_18_de_Marzo', 'Martin_Carrera', 'Bellas_artes'], ['La_Raza', 'Atlalilco', 'San_Lazaro', 'Pino_suarez', 'Balderas', 'Tacubaya', 'Tacuba', 'Deportivo_18_de_Marzo', 'Martin_Carrera', 'Bellas_artes'], ['La_Raza', 'Atlalilco', 'San_Lazaro', 'Pino_suarez', 'Balderas', 'Tacubaya', 'Tacuba', 'Deportivo_18_de_Marzo', 'Martin_Carrera', 'Bellas_artes']]
# [['La_Raza', 'Atlalilco', 'San_Lazaro', 'Pino_suarez', 'Balderas', 'Tacubaya', 'Tacuba', 'Deportivo_18_de_Marzo', 'Martin_Carrera', 'Bellas_artes'], ['La_Raza', 'Atlalilco', 'San_Lazaro', 'Pino_suarez', 'Balderas', 'Tacubaya', 'Tacuba', 'Deportivo_18_de_Marzo', 'Martin_Carrera', 'Bellas_artes'], ['La_Raza', 'Atlalilco', 'San_Lazaro', 'Pino_suarez', 'Balderas', 'Tacubaya', 'Tacuba', 'Deportivo_18_de_Marzo', 'Martin_Carrera', 'Bellas_artes'], ['La_Raza', 'Atlalilco', 'San_Lazaro', 'Pino_suarez', 'Balderas', 'Tacubaya', 'Tacuba', 'Deportivo_18_de_Marzo', 'Martin_Carrera', 'Bellas_artes'], ['La_Raza', 'Atlalilco', 'San_Lazaro', 'Pino_suarez', 'Balderas', 'Tacubaya', 'Tacuba', 'Deportivo_18_de_Marzo', 'Martin_Carrera', 'Bellas_artes'], ['La_Raza', 'Atlalilco', 'San_Lazaro', 'Pino_suarez', 'Balderas', 'Tacubaya', 'Tacuba', 'Deportivo_18_de_Marzo', 'Martin_Carrera', 'Bellas_artes'], ['La_Raza', 'Atlalilco', 'San_Lazaro', 'Pino_suarez', 'Balderas', 'Tacubaya', 'Tacuba', 'Deportivo_18_de_Marzo', 'Martin_Carrera', 'Bellas_artes'], ['La_Raza', 'Atlalilco', 'San_Lazaro', 'Pino_suarez', 'Balderas', 'Tacubaya', 'Tacuba', 'Deportivo_18_de_Marzo', 'Martin_Carrera', 'Bellas_artes'], ['La_Raza', 'Atlalilco', 'San_Lazaro', 'Pino_suarez', 'Balderas', 'Tacubaya', 'Tacuba', 'Deportivo_18_de_Marzo', 'Martin_Carrera', 'Bellas_artes'], ['La_Raza', 'Atlalilco', 'San_Lazaro', 'Pino_suarez', 'Balderas', 'Tacubaya', 'Tacuba', 'Deportivo_18_de_Marzo', 'Martin_Carrera', 'Bellas_artes'], ['La_Raza', 'Atlalilco', 'San_Lazaro', 'Pino_suarez', 'Balderas', 'Tacubaya', 'Tacuba', 'Deportivo_18_de_Marzo', 'Martin_Carrera', 'Bellas_artes'], ['La_Raza', 'Atlalilco', 'San_Lazaro', 'Pino_suarez', 'Balderas', 'Tacubaya', 'Tacuba', 'Deportivo_18_de_Marzo', 'Martin_Carrera', 'Bellas_artes'], ['La_Raza', 'Atlalilco', 'San_Lazaro', 'Pino_suarez', 'Balderas', 'Tacubaya', 'Tacuba', 'Deportivo_18_de_Marzo', 'Martin_Carrera', 'Bellas_artes'], ['La_Raza', 'Atlalilco', 'San_Lazaro', 'Pino_suarez', 'Balderas', 'Tacubaya', 'Tacuba', 'Deportivo_18_de_Marzo', 'Martin_Carrera', 'Bellas_artes'], ['La_Raza', 'Atlalilco', 'San_Lazaro', 'Pino_suarez', 'Balderas', 'Tacubaya', 'Tacuba', 'Deportivo_18_de_Marzo', 'Martin_Carrera', 'Bellas_artes'], ['La_Raza', 'Atlalilco', 'San_Lazaro', 'Pino_suarez', 'Balderas', 'Tacubaya', 'Tacuba', 'Deportivo_18_de_Marzo', 'Martin_Carrera', 'Bellas_artes'], ['La_Raza', 'Atlalilco', 'San_Lazaro', 'Pino_suarez', 'Balderas', 'Tacubaya', 'Tacuba', 'Deportivo_18_de_Marzo', 'Martin_Carrera', 'Bellas_artes'], ['La_Raza', 'Atlalilco', 'San_Lazaro', 'Pino_suarez', 'Balderas', 'Tacubaya', 'Tacuba', 'Deportivo_18_de_Marzo', 'Martin_Carrera', 'Bellas_artes'], ['La_Raza', 'Atlalilco', 'San_Lazaro', 'Pino_suarez', 'Balderas', 'Tacubaya', 'Tacuba', 'Deportivo_18_de_Marzo', 'Martin_Carrera', 'Bellas_artes'], ['La_Raza', 'Atlalilco', 'San_Lazaro', 'Pino_suarez', 'Balderas', 'Tacubaya', 'Tacuba', 'Deportivo_18_de_Marzo', 'Martin_Carrera', 'Bellas_artes']]

# %% [markdown]
# ## La función mutation() se encargara de mutar de manera aleatoria a los individuos de una población, la probabilidad de mutar esta dada por **mutation_chance**. El individuo muta seleccionando una estación al azar y cambiando su valor

# %%
def mutation(population):
    """
        Se mutan los individuos al azar.
    """
    for i in range(len(population)-pressure):
      if random.random() <= mutation_chance: #Cada individuo de la poblacion (menos los padres) tienen una probabilidad de mutar
        punto = random.randint(0,largo-1) #Se elgie un punto al azar
        nuevo_valor = random.choice(list(dicctionaryValuesNode.keys()))  #y un nuevo valor para este punto

        #Es importante mirar que el nuevo valor no sea igual al viejo
        while nuevo_valor == population[i][punto]:
            nuevo_valor = random.choice(list(dicctionaryValuesNode.keys()))

        #Se aplica la mutacion
        population[i][punto] = nuevo_valor
        #print(f"Individuo mutado: {population[i]}")
    return population

# %%
#Test mutation()
other_poblacion = crearPoblacion()
for i in range(5):
  print(mutation(other_poblacion))
# Out:
# [['Mixcoac', 'CentroMedico', 'Oceania', 'Universidad', 'Garibaldi', 'Tacubaya', 'La_Villa_Basilica', 'Bellas_artes', 'Chabacano', 'Morelos'], ['Atlalilco', 'Salto_del_agua', 'Morelos', 'San_Lazaro', 'Guerrero', 'Mixcoac', 'Santa_Anita', 'Martin_Carrera', 'La_Villa_Basilica', 'Garibaldi'], ['La_Villa_Basilica', 'Instituto_del_petroleo', 'Garibaldi', 'Bellas_artes', 'Balderas', 'Atlalilco', 'CentroMedico', 'Santa_Anita', 'San_Lazaro', 'Pino_suarez'], ['San_Lazaro', 'Atlalilco', 'Pantitlan', 'Instituto_del_petroleo', 'Tacubaya', 'La_Villa_Basilica', 'Morelos', 'Tacuba', 'Santa_Anita', 'El_rosario'], ['Mixcoac', 'Garibaldi', 'San_Lazaro', 'Zapata', 'Hidalgo', 'Chabacano', 'Pantitlan', 'Tacubaya', 'Oceania', 'Candelaria'], ['San_Lazaro', 'Consulado', 'Deportivo_18_de_Marzo', 'Balderas', 'Oceania', 'Santa_Anita', 'Oceania', 'Mixcoac', 'Tacuba', 'Pino_suarez'], ['Pantitlan', 'Consulado', 'Atlalilco', 'Pino_suarez', 'Hidalgo', 'Guerrero', 'Atlalilco', 'Martin_Carrera', 'Instituto_del_petroleo', 'San_Lazaro'], ['Guerrero', 'Chabacano', 'Candelaria', 'Jamaica', 'Tacubaya', 'Salto_del_agua', 'La_Villa_Basilica', 'San_Lazaro', 'Tacuba', 'Hidalgo'], ['Instituto_del_petroleo', 'Ermita', 'La_Villa_Basilica', 'Oceania', 'Tacubaya', 'Santa_Anita', 'El_rosario', 'Tacubaya', 'Pantitlan', 'Salto_del_agua'], ['Oceania', 'Hidalgo', 'Mixcoac', 'Consulado', 'Guerrero', 'Candelaria', 'CentroMedico', 'Balderas', 'La_Villa_Basilica', 'Tacubaya'], ['Universidad', 'Zapata', 'Balderas', 'Bellas_artes', 'Morelos', 'Martin_Carrera', 'Hidalgo', 'Atlalilco', 'Garibaldi', 'Tacuba'], ['Mixcoac', 'Guerrero', 'Salto_del_agua', 'Instituto_del_petroleo', 'La_Villa_Basilica', 'Hidalgo', 'Tacubaya', 'Jamaica', 'Bellas_artes', 'Tacuba'], ['Santa_Anita', 'Candelaria', 'Tacubaya', 'Ermita', 'Oceania', 'Bellas_artes', 'San_Lazaro', 'Deportivo_18_de_Marzo', 'Tacuba', 'Salto_del_agua'], ['Oceania', 'La_Raza', 'Pino_suarez', 'Instituto_del_petroleo', 'La_Villa_Basilica', 'Atlalilco', 'Consulado', 'Hidalgo', 'Ermita', 'Morelos'], ['Mixcoac', 'Guerrero', 'Instituto_del_petroleo', 'Chabacano', 'Balderas', 'Hidalgo', 'Salto_del_agua', 'Bellas_artes', 'Tacuba', 'Oceania'], ['Santa_Anita', 'La_Raza', 'Guerrero', 'Morelos', 'CentroMedico', 'San_Lazaro', 'Hidalgo', 'Consulado', 'Universidad', 'Ermita'], ['CentroMedico', 'Hidalgo', 'Tacuba', 'El_rosario', 'Bellas_artes', 'Consulado', 'Mixcoac', 'La_Villa_Basilica', 'Jamaica', 'Instituto_del_petroleo'], ['Pino_suarez', 'Bellas_artes', 'CentroMedico', 'Candelaria', 'La_Raza', 'Salto_del_agua', 'Garibaldi', 'Zapata', 'Santa_Anita', 'Morelos'], ['El_rosario', 'Bellas_artes', 'Deportivo_18_de_Marzo', 'Chabacano', 'La_Villa_Basilica', 'Atlalilco', 'Tacubaya', 'Candelaria', 'Universidad', 'CentroMedico'], ['Martin_Carrera', 'Candelaria', 'Salto_del_agua', 'Garibaldi', 'Oceania', 'Bellas_artes', 'Balderas', 'Jamaica', 'Morelos', 'Tacuba']]
# [['Mixcoac', 'CentroMedico', 'Oceania', 'Universidad', 'Garibaldi', 'Tacubaya', 'La_Villa_Basilica', 'Bellas_artes', 'Chabacano', 'Morelos'], ['Atlalilco', 'Salto_del_agua', 'Morelos', 'San_Lazaro', 'Guerrero', 'Mixcoac', 'Santa_Anita', 'Martin_Carrera', 'La_Villa_Basilica', 'Garibaldi'], ['La_Villa_Basilica', 'Instituto_del_petroleo', 'Garibaldi', 'Bellas_artes', 'Balderas', 'Atlalilco', 'CentroMedico', 'Santa_Anita', 'Garibaldi', 'Pino_suarez'], ['Martin_Carrera', 'Atlalilco', 'Pantitlan', 'Instituto_del_petroleo', 'Tacubaya', 'La_Villa_Basilica', 'Morelos', 'Tacuba', 'Santa_Anita', 'El_rosario'], ['Mixcoac', 'Garibaldi', 'San_Lazaro', 'Zapata', 'Hidalgo', 'Chabacano', 'Pantitlan', 'Tacubaya', 'Oceania', 'Candelaria'], ['San_Lazaro', 'Consulado', 'Deportivo_18_de_Marzo', 'Balderas', 'Zapata', 'Santa_Anita', 'Oceania', 'Mixcoac', 'Tacuba', 'Pino_suarez'], ['Pantitlan', 'Consulado', 'Atlalilco', 'Pino_suarez', 'Hidalgo', 'Guerrero', 'Atlalilco', 'Martin_Carrera', 'Instituto_del_petroleo', 'San_Lazaro'], ['Guerrero', 'Chabacano', 'Candelaria', 'Jamaica', 'Tacubaya', 'Salto_del_agua', 'La_Villa_Basilica', 'San_Lazaro', 'Tacuba', 'Hidalgo'], ['Instituto_del_petroleo', 'Ermita', 'Pino_suarez', 'Oceania', 'Tacubaya', 'Santa_Anita', 'El_rosario', 'Tacubaya', 'Pantitlan', 'Salto_del_agua'], ['Oceania', 'Hidalgo', 'Mixcoac', 'Consulado', 'Guerrero', 'Candelaria', 'CentroMedico', 'Balderas', 'La_Villa_Basilica', 'Tacubaya'], ['Universidad', 'Zapata', 'Balderas', 'Bellas_artes', 'Atlalilco', 'Martin_Carrera', 'Hidalgo', 'Atlalilco', 'Garibaldi', 'Tacuba'], ['Mixcoac', 'Guerrero', 'Salto_del_agua', 'Instituto_del_petroleo', 'La_Villa_Basilica', 'Hidalgo', 'Tacubaya', 'Jamaica', 'Bellas_artes', 'Tacuba'], ['Santa_Anita', 'Candelaria', 'Tacubaya', 'Ermita', 'Oceania', 'Bellas_artes', 'San_Lazaro', 'El_rosario', 'Tacuba', 'Salto_del_agua'], ['Oceania', 'La_Raza', 'Pino_suarez', 'Instituto_del_petroleo', 'La_Villa_Basilica', 'Atlalilco', 'Consulado', 'Morelos', 'Ermita', 'Morelos'], ['Mixcoac', 'Guerrero', 'Instituto_del_petroleo', 'Chabacano', 'Balderas', 'Hidalgo', 'Salto_del_agua', 'Bellas_artes', 'Tacuba', 'Oceania'], ['Santa_Anita', 'La_Raza', 'Guerrero', 'Morelos', 'CentroMedico', 'San_Lazaro', 'Hidalgo', 'Consulado', 'Universidad', 'Ermita'], ['CentroMedico', 'Hidalgo', 'Tacuba', 'El_rosario', 'Bellas_artes', 'Consulado', 'Mixcoac', 'La_Villa_Basilica', 'Jamaica', 'Instituto_del_petroleo'], ['Pino_suarez', 'Bellas_artes', 'CentroMedico', 'Candelaria', 'La_Raza', 'Salto_del_agua', 'Garibaldi', 'Zapata', 'Santa_Anita', 'Morelos'], ['El_rosario', 'Bellas_artes', 'Deportivo_18_de_Marzo', 'Chabacano', 'La_Villa_Basilica', 'Atlalilco', 'Tacubaya', 'Candelaria', 'Universidad', 'CentroMedico'], ['Martin_Carrera', 'Candelaria', 'Salto_del_agua', 'Garibaldi', 'Oceania', 'Bellas_artes', 'Balderas', 'Jamaica', 'Morelos', 'Tacuba']]
# [['Mixcoac', 'CentroMedico', 'El_rosario', 'Universidad', 'Garibaldi', 'Tacubaya', 'La_Villa_Basilica', 'Bellas_artes', 'Chabacano', 'Morelos'], ['Atlalilco', 'Salto_del_agua', 'Morelos', 'San_Lazaro', 'Guerrero', 'Mixcoac', 'Santa_Anita', 'Martin_Carrera', 'La_Villa_Basilica', 'Garibaldi'], ['La_Villa_Basilica', 'Instituto_del_petroleo', 'Garibaldi', 'Bellas_artes', 'Balderas', 'Atlalilco', 'CentroMedico', 'Santa_Anita', 'Tacubaya', 'Pino_suarez'], ['Martin_Carrera', 'Atlalilco', 'Pantitlan', 'Instituto_del_petroleo', 'Tacubaya', 'La_Villa_Basilica', 'Morelos', 'Tacuba', 'Santa_Anita', 'El_rosario'], ['Mixcoac', 'Garibaldi', 'San_Lazaro', 'Zapata', 'Hidalgo', 'Chabacano', 'Pantitlan', 'Tacubaya', 'Oceania', 'Candelaria'], ['San_Lazaro', 'Consulado', 'Deportivo_18_de_Marzo', 'Balderas', 'Zapata', 'Santa_Anita', 'Oceania', 'Mixcoac', 'Bellas_artes', 'Pino_suarez'], ['Pantitlan', 'Consulado', 'Atlalilco', 'Pino_suarez', 'Hidalgo', 'Guerrero', 'Atlalilco', 'Martin_Carrera', 'Instituto_del_petroleo', 'San_Lazaro'], ['Guerrero', 'Chabacano', 'Candelaria', 'Jamaica', 'Tacubaya', 'Salto_del_agua', 'La_Villa_Basilica', 'San_Lazaro', 'Tacuba', 'Hidalgo'], ['Instituto_del_petroleo', 'Ermita', 'Pino_suarez', 'Oceania', 'Tacubaya', 'Santa_Anita', 'El_rosario', 'Tacubaya', 'Pantitlan', 'Salto_del_agua'], ['Oceania', 'Hidalgo', 'Mixcoac', 'Consulado', 'Guerrero', 'Candelaria', 'CentroMedico', 'Balderas', 'La_Villa_Basilica', 'Tacubaya'], ['Universidad', 'Zapata', 'Balderas', 'Bellas_artes', 'Atlalilco', 'Martin_Carrera', 'Hidalgo', 'Atlalilco', 'Instituto_del_petroleo', 'Tacuba'], ['Mixcoac', 'Guerrero', 'Salto_del_agua', 'Instituto_del_petroleo', 'La_Villa_Basilica', 'Hidalgo', 'Tacubaya', 'Jamaica', 'Bellas_artes', 'Tacuba'], ['Santa_Anita', 'Candelaria', 'Tacubaya', 'Ermita', 'Oceania', 'Bellas_artes', 'San_Lazaro', 'El_rosario', 'Tacuba', 'Santa_Anita'], ['Oceania', 'La_Raza', 'Pino_suarez', 'Instituto_del_petroleo', 'Chabacano', 'Atlalilco', 'Consulado', 'Morelos', 'Ermita', 'Morelos'], ['Mixcoac', 'Guerrero', 'Instituto_del_petroleo', 'Chabacano', 'Balderas', 'Hidalgo', 'Salto_del_agua', 'Bellas_artes', 'Tacuba', 'Oceania'], ['Santa_Anita', 'La_Raza', 'Guerrero', 'CentroMedico', 'CentroMedico', 'San_Lazaro', 'Hidalgo', 'Consulado', 'Universidad', 'Ermita'], ['CentroMedico', 'Hidalgo', 'Tacuba', 'El_rosario', 'Bellas_artes', 'Consulado', 'Mixcoac', 'La_Villa_Basilica', 'Jamaica', 'Instituto_del_petroleo'], ['Pino_suarez', 'Bellas_artes', 'CentroMedico', 'Candelaria', 'La_Raza', 'Salto_del_agua', 'Garibaldi', 'Zapata', 'Santa_Anita', 'Morelos'], ['El_rosario', 'Bellas_artes', 'Deportivo_18_de_Marzo', 'Chabacano', 'La_Villa_Basilica', 'Atlalilco', 'Tacubaya', 'Candelaria', 'Universidad', 'CentroMedico'], ['Martin_Carrera', 'Candelaria', 'Salto_del_agua', 'Garibaldi', 'Oceania', 'Bellas_artes', 'Balderas', 'Jamaica', 'Morelos', 'Tacuba']]
# [['Mixcoac', 'CentroMedico', 'El_rosario', 'Universidad', 'Garibaldi', 'Tacubaya', 'La_Villa_Basilica', 'Bellas_artes', 'Chabacano', 'Morelos'], ['Atlalilco', 'Salto_del_agua', 'Morelos', 'San_Lazaro', 'Guerrero', 'Mixcoac', 'Santa_Anita', 'Martin_Carrera', 'La_Villa_Basilica', 'Garibaldi'], ['La_Villa_Basilica', 'Instituto_del_petroleo', 'Garibaldi', 'Bellas_artes', 'Balderas', 'Atlalilco', 'San_Lazaro', 'Santa_Anita', 'Tacubaya', 'Pino_suarez'], ['Martin_Carrera', 'Atlalilco', 'Pantitlan', 'Instituto_del_petroleo', 'Tacubaya', 'La_Villa_Basilica', 'Morelos', 'Tacuba', 'Santa_Anita', 'El_rosario'], ['Mixcoac', 'Garibaldi', 'San_Lazaro', 'Zapata', 'Hidalgo', 'Chabacano', 'Pantitlan', 'Tacubaya', 'Oceania', 'Candelaria'], ['San_Lazaro', 'Consulado', 'Deportivo_18_de_Marzo', 'Balderas', 'Zapata', 'Santa_Anita', 'Oceania', 'Mixcoac', 'Bellas_artes', 'Pino_suarez'], ['Morelos', 'Consulado', 'Atlalilco', 'Pino_suarez', 'Hidalgo', 'Guerrero', 'Atlalilco', 'Martin_Carrera', 'Instituto_del_petroleo', 'San_Lazaro'], ['Guerrero', 'Chabacano', 'Candelaria', 'Jamaica', 'Tacubaya', 'Santa_Anita', 'La_Villa_Basilica', 'San_Lazaro', 'Tacuba', 'Hidalgo'], ['Instituto_del_petroleo', 'Ermita', 'El_rosario', 'Oceania', 'Tacubaya', 'Santa_Anita', 'El_rosario', 'Tacubaya', 'Pantitlan', 'Salto_del_agua'], ['Oceania', 'Hidalgo', 'Mixcoac', 'Consulado', 'Guerrero', 'Candelaria', 'CentroMedico', 'Balderas', 'La_Villa_Basilica', 'Tacubaya'], ['Universidad', 'Zapata', 'Balderas', 'Bellas_artes', 'Atlalilco', 'Martin_Carrera', 'Hidalgo', 'Deportivo_18_de_Marzo', 'Instituto_del_petroleo', 'Tacuba'], ['Mixcoac', 'Guerrero', 'Salto_del_agua', 'Instituto_del_petroleo', 'La_Villa_Basilica', 'Hidalgo', 'Tacubaya', 'Jamaica', 'Bellas_artes', 'Tacuba'], ['Santa_Anita', 'Candelaria', 'Tacubaya', 'Ermita', 'Oceania', 'Bellas_artes', 'San_Lazaro', 'El_rosario', 'Tacuba', 'Santa_Anita'], ['Pantitlan', 'La_Raza', 'Pino_suarez', 'Instituto_del_petroleo', 'Chabacano', 'Atlalilco', 'Consulado', 'Morelos', 'Ermita', 'Morelos'], ['Mixcoac', 'Guerrero', 'Instituto_del_petroleo', 'Chabacano', 'Balderas', 'Candelaria', 'Salto_del_agua', 'Bellas_artes', 'Tacuba', 'Oceania'], ['Santa_Anita', 'La_Raza', 'Guerrero', 'CentroMedico', 'CentroMedico', 'San_Lazaro', 'Hidalgo', 'Atlalilco', 'Universidad', 'Ermita'], ['CentroMedico', 'Hidalgo', 'Tacuba', 'El_rosario', 'Bellas_artes', 'Consulado', 'Mixcoac', 'La_Villa_Basilica', 'Jamaica', 'Instituto_del_petroleo'], ['Pino_suarez', 'Bellas_artes', 'CentroMedico', 'Candelaria', 'La_Raza', 'Salto_del_agua', 'Garibaldi', 'Zapata', 'Santa_Anita', 'Morelos'], ['El_rosario', 'Bellas_artes', 'Deportivo_18_de_Marzo', 'Chabacano', 'La_Villa_Basilica', 'Atlalilco', 'Tacubaya', 'Candelaria', 'Universidad', 'CentroMedico'], ['Martin_Carrera', 'Candelaria', 'Salto_del_agua', 'Garibaldi', 'Oceania', 'Bellas_artes', 'Balderas', 'Jamaica', 'Morelos', 'Tacuba']]
# [['Mixcoac', 'CentroMedico', 'El_rosario', 'Universidad', 'Garibaldi', 'Tacubaya', 'La_Villa_Basilica', 'Bellas_artes', 'Chabacano', 'Morelos'], ['Atlalilco', 'Salto_del_agua', 'Morelos', 'San_Lazaro', 'Guerrero', 'Mixcoac', 'Santa_Anita', 'Martin_Carrera', 'La_Villa_Basilica', 'Garibaldi'], ['La_Villa_Basilica', 'Instituto_del_petroleo', 'Garibaldi', 'Bellas_artes', 'Balderas', 'Atlalilco', 'San_Lazaro', 'Santa_Anita', 'Tacubaya', 'Pino_suarez'], ['Martin_Carrera', 'Atlalilco', 'Pantitlan', 'Instituto_del_petroleo', 'Tacubaya', 'La_Villa_Basilica', 'Morelos', 'Tacuba', 'Santa_Anita', 'El_rosario'], ['Mixcoac', 'Garibaldi', 'San_Lazaro', 'Zapata', 'Hidalgo', 'Chabacano', 'Pantitlan', 'Tacubaya', 'Oceania', 'Candelaria'], ['San_Lazaro', 'Consulado', 'Deportivo_18_de_Marzo', 'Balderas', 'Zapata', 'Santa_Anita', 'Oceania', 'Mixcoac', 'Bellas_artes', 'Pino_suarez'], ['Morelos', 'Consulado', 'Atlalilco', 'Pino_suarez', 'Hidalgo', 'Guerrero', 'Atlalilco', 'Martin_Carrera', 'Instituto_del_petroleo', 'San_Lazaro'], ['Guerrero', 'Chabacano', 'Candelaria', 'Jamaica', 'Tacubaya', 'Santa_Anita', 'La_Villa_Basilica', 'San_Lazaro', 'Tacuba', 'Hidalgo'], ['Instituto_del_petroleo', 'Ermita', 'El_rosario', 'Oceania', 'Tacubaya', 'Santa_Anita', 'El_rosario', 'Tacubaya', 'Pantitlan', 'Salto_del_agua'], ['Oceania', 'Hidalgo', 'Mixcoac', 'Consulado', 'Guerrero', 'Candelaria', 'CentroMedico', 'Balderas', 'La_Villa_Basilica', 'Tacubaya'], ['Universidad', 'Zapata', 'Balderas', 'Bellas_artes', 'Atlalilco', 'Martin_Carrera', 'Hidalgo', 'Deportivo_18_de_Marzo', 'Instituto_del_petroleo', 'Tacuba'], ['Mixcoac', 'Guerrero', 'Salto_del_agua', 'Instituto_del_petroleo', 'La_Villa_Basilica', 'Hidalgo', 'Tacubaya', 'Jamaica', 'Bellas_artes', 'Tacuba'], ['Santa_Anita', 'Candelaria', 'Tacubaya', 'Ermita', 'Oceania', 'Bellas_artes', 'San_Lazaro', 'El_rosario', 'Tacuba', 'Santa_Anita'], ['Pantitlan', 'La_Raza', 'Pino_suarez', 'Instituto_del_petroleo', 'Chabacano', 'Atlalilco', 'Consulado', 'Santa_Anita', 'Ermita', 'Morelos'], ['Mixcoac', 'Guerrero', 'Instituto_del_petroleo', 'Chabacano', 'Balderas', 'Candelaria', 'Salto_del_agua', 'Bellas_artes', 'Tacuba', 'Oceania'], ['Santa_Anita', 'La_Raza', 'Guerrero', 'CentroMedico', 'CentroMedico', 'San_Lazaro', 'Hidalgo', 'Atlalilco', 'Universidad', 'Ermita'], ['CentroMedico', 'Hidalgo', 'Tacuba', 'El_rosario', 'Bellas_artes', 'Consulado', 'Mixcoac', 'La_Villa_Basilica', 'Jamaica', 'Instituto_del_petroleo'], ['Pino_suarez', 'Bellas_artes', 'CentroMedico', 'Candelaria', 'La_Raza', 'Salto_del_agua', 'Garibaldi', 'Zapata', 'Santa_Anita', 'Morelos'], ['El_rosario', 'Bellas_artes', 'Deportivo_18_de_Marzo', 'Chabacano', 'La_Villa_Basilica', 'Atlalilco', 'Tacubaya', 'Candelaria', 'Universidad', 'CentroMedico'], ['Martin_Carrera', 'Candelaria', 'Salto_del_agua', 'Garibaldi', 'Oceania', 'Bellas_artes', 'Balderas', 'Jamaica', 'Morelos', 'Tacuba']]

# %%
import matplotlib.pyplot as plt

population = crearPoblacion()#Inicializar una poblacion
evoluciones = 300
averageFitness = []
print("Poblacion Inicial:\n%s"%(population)) #Se muestra la poblacion inicial
#for i in range(len(population)):
#  print(f"Fitness: {calcularFitness(population[i])} \tIndividuo: {population[i]}")

#Se evoluciona la poblacion
for i in range(evoluciones):
  averageFitness.append(averageFitnessPoblacion(population))
  population = selection_and_reproduction(population)
  #print("\nPoblacion Reproducida:\n%s"%(population)) #Se muestra la poblacion reproducida
  population = mutation(population)
  #print("\nPoblacion Mutada:\n%s"%(population)) #Se muestra la poblacion mutada

print("\nPoblacion Final:\n%s"%(population)) #Se muestra la poblacion evolucionada
#for i in range(len(population)):
#  print(f"Fitness: {calcularFitness(population[i])} \tIndividuo: {population[i]}")
print("\n")

print(f"Modelo objetivo: {modelo}")
print(f"Fitness del modelo objetivo: {calcularFitness(modelo)[0]}\n")

best_individuo = max(population, key=calcularFitness)
if verificar_y_reordenar_individuo(best_individuo,dictionaryConexionStations)[0]:
  print(f"El mejor individuo de la útima generación tiene conexiones directas de acuerdo a lo establecido, por lo tanto es posible realizar ese recorrido\n")
  print(f"Best Individuo: {verificar_y_reordenar_individuo(best_individuo,dictionaryConexionStations)[1]}")
else:
  print(f"El mejor individuo de la útima generación no tiene conexiones directas de acuerdo a lo establecido, por lo tanto no es posible realizar ese recorrido\n")
  print(f"Best individuo: {best_individuo}")

print(f"Fitness: {calcularFitness(best_individuo)[0]}")
print(f"Tiempo de viaje: {calcularFitness(best_individuo)[1]} min")
print(f"Sitios visitados: {calcularFitness(best_individuo)[2]}")

#Grafica del rendimieto en cada iteracion
plt.plot(range(evoluciones), averageFitness)
plt.xlabel("Iteration")
plt.ylabel("Average Fitness")
plt.title("Average Fitness vs Iterations")
plt.show()
# Out:
# Poblacion Inicial:
# [['Pantitlan', 'Instituto_del_petroleo', 'Atlalilco', 'Bellas_artes', 'Universidad', 'Ermita', 'Salto_del_agua', 'Oceania', 'Consulado', 'Mixcoac'], ['La_Raza', 'Morelos', 'Jamaica', 'Hidalgo', 'Garibaldi', 'Santa_Anita', 'Tacubaya', 'Mixcoac', 'El_rosario', 'Consulado'], ['Pino_suarez', 'Hidalgo', 'Pantitlan', 'Tacubaya', 'San_Lazaro', 'Tacuba', 'Oceania', 'La_Raza', 'Balderas', 'La_Villa_Basilica'], ['Santa_Anita', 'Chabacano', 'Pino_suarez', 'Guerrero', 'Deportivo_18_de_Marzo', 'Mixcoac', 'CentroMedico', 'Martin_Carrera', 'Morelos', 'San_Lazaro'], ['Jamaica', 'CentroMedico', 'San_Lazaro', 'Atlalilco', 'Martin_Carrera', 'Deportivo_18_de_Marzo', 'Garibaldi', 'Pantitlan', 'Bellas_artes', 'La_Villa_Basilica'], ['Bellas_artes', 'CentroMedico', 'Universidad', 'Chabacano', 'San_Lazaro', 'Tacuba', 'Hidalgo', 'Tacubaya', 'Pino_suarez', 'Atlalilco'], ['Martin_Carrera', 'Jamaica', 'Tacuba', 'La_Villa_Basilica', 'Consulado', 'Garibaldi', 'Candelaria', 'Atlalilco', 'Guerrero', 'Ermita'], ['Santa_Anita', 'Jamaica', 'CentroMedico', 'Mixcoac', 'San_Lazaro', 'El_rosario', 'Atlalilco', 'Universidad', 'Candelaria', 'Salto_del_agua'], ['Atlalilco', 'Consulado', 'Chabacano', 'Santa_Anita', 'Universidad', 'La_Raza', 'Balderas', 'Garibaldi', 'Mixcoac', 'Tacuba'], ['Balderas', 'Pino_suarez', 'Salto_del_agua', 'Ermita', 'Jamaica', 'Pantitlan', 'Universidad', 'Garibaldi', 'San_Lazaro', 'Consulado'], ['Pino_suarez', 'Zapata', 'Salto_del_agua', 'Ermita', 'Tacuba', 'Bellas_artes', 'Jamaica', 'Oceania', 'Santa_Anita', 'Balderas'], ['Zapata', 'Garibaldi', 'La_Villa_Basilica', 'Salto_del_agua', 'Balderas', 'CentroMedico', 'Instituto_del_petroleo', 'Deportivo_18_de_Marzo', 'Hidalgo', 'Tacubaya'], ['Pino_suarez', 'Pantitlan', 'Candelaria', 'Bellas_artes', 'Zapata', 'Chabacano', 'Universidad', 'Ermita', 'Consulado', 'Santa_Anita'], ['Balderas', 'Salto_del_agua', 'Martin_Carrera', 'Jamaica', 'Ermita', 'Pino_suarez', 'Hidalgo', 'Pantitlan', 'Garibaldi', 'La_Raza'], ['Pino_suarez', 'Mixcoac', 'La_Raza', 'Ermita', 'Candelaria', 'Zapata', 'Tacuba', 'Oceania', 'Deportivo_18_de_Marzo', 'Morelos'], ['La_Raza', 'Jamaica', 'Universidad', 'Atlalilco', 'Martin_Carrera', 'Oceania', 'Candelaria', 'CentroMedico', 'Garibaldi', 'Zapata'], ['CentroMedico', 'Tacubaya', 'Morelos', 'Garibaldi', 'Pino_suarez', 'Universidad', 'Consulado', 'Mixcoac', 'La_Villa_Basilica', 'Atlalilco'], ['Candelaria', 'La_Raza', 'Tacuba', 'Oceania', 'Hidalgo', 'Martin_Carrera', 'Balderas', 'Mixcoac', 'Bellas_artes', 'Salto_del_agua'], ['Pantitlan', 'Oceania', 'Salto_del_agua', 'Bellas_artes', 'Tacuba', 'El_rosario', 'Balderas', 'Jamaica', 'Martin_Carrera', 'Guerrero'], ['Tacuba', 'Candelaria', 'Pantitlan', 'Balderas', 'Consulado', 'Instituto_del_petroleo', 'Guerrero', 'San_Lazaro', 'Mixcoac', 'El_rosario']]
#
# Poblacion Final:
# [['Bellas_artes', 'Garibaldi', 'San_Lazaro', 'Hidalgo', 'Balderas', 'Salto_del_agua', 'Pino_suarez', 'Candelaria', 'Morelos', 'San_Lazaro'], ['Bellas_artes', 'Garibaldi', 'Guerrero', 'Hidalgo', 'Balderas', 'Salto_del_agua', 'Pino_suarez', 'Candelaria', 'Morelos', 'San_Lazaro'], ['Bellas_artes', 'Garibaldi', 'Guerrero', 'Hidalgo', 'Balderas', 'Salto_del_agua', 'Pino_suarez', 'Candelaria', 'Morelos', 'San_Lazaro'], ['Bellas_artes', 'Garibaldi', 'Guerrero', 'Hidalgo', 'Balderas', 'Salto_del_agua', 'Pino_suarez', 'Candelaria', 'Morelos', 'San_Lazaro'], ['Bellas_artes', 'Garibaldi', 'Guerrero', 'Hidalgo', 'Balderas', 'Salto_del_agua', 'Pino_suarez', 'Guerrero', 'Morelos', 'San_Lazaro'], ['Bellas_artes', 'Garibaldi', 'Guerrero', 'Hidalgo', 'Balderas', 'Salto_del_agua', 'Pino_suarez', 'Candelaria', 'Morelos', 'San_Lazaro'], ['Bellas_artes', 'Garibaldi', 'Guerrero', 'Hidalgo', 'Balderas', 'Salto_del_agua', 'Pino_suarez', 'Candelaria', 'Morelos', 'San_Lazaro'], ['Bellas_artes', 'Garibaldi', 'Guerrero', 'Hidalgo', 'Balderas', 'Salto_del_agua', 'Pino_suarez', 'Candelaria', 'Morelos', 'San_Lazaro'], ['Bellas_artes', 'Garibaldi', 'Guerrero', 'Hidalgo', 'Balderas', 'Salto_del_agua', 'Pino_suarez', 'Candelaria', 'Morelos', 'San_Lazaro'], ['Bellas_artes', 'Garibaldi', 'Guerrero', 'Hidalgo', 'Balderas', 'Salto_del_agua', 'Pino_suarez', 'Candelaria', 'Morelos', 'San_Lazaro'], ['Bellas_artes', 'Garibaldi', 'Guerrero', 'Hidalgo', 'Balderas', 'Salto_del_agua', 'Pino_suarez', 'Candelaria', 'Morelos', 'San_Lazaro'], ['Bellas_artes', 'Garibaldi', 'Guerrero', 'Hidalgo', 'Balderas', 'Salto_del_agua', 'CentroMedico', 'Candelaria', 'Morelos', 'San_Lazaro'], ['Bellas_artes', 'Garibaldi', 'Guerrero', 'Hidalgo', 'Balderas', 'Salto_del_agua', 'Pino_suarez', 'Candelaria', 'Morelos', 'San_Lazaro'], ['Bellas_artes', 'La_Villa_Basilica', 'Guerrero', 'Hidalgo', 'Balderas', 'Salto_del_agua', 'Pino_suarez', 'Candelaria', 'Morelos', 'San_Lazaro'], ['Bellas_artes', 'Garibaldi', 'Guerrero', 'Hidalgo', 'Balderas', 'Salto_del_agua', 'Pino_suarez', 'La_Villa_Basilica', 'Morelos', 'San_Lazaro'], ['Bellas_artes', 'Garibaldi', 'Guerrero', 'Hidalgo', 'Balderas', 'Salto_del_agua', 'Pino_suarez', 'Candelaria', 'Morelos', 'San_Lazaro'], ['Bellas_artes', 'Garibaldi', 'Guerrero', 'Hidalgo', 'Balderas', 'Salto_del_agua', 'Pino_suarez', 'Candelaria', 'Morelos', 'San_Lazaro'], ['Bellas_artes', 'Garibaldi', 'Guerrero', 'Hidalgo', 'Balderas', 'Salto_del_agua', 'Pino_suarez', 'Candelaria', 'Morelos', 'San_Lazaro'], ['Bellas_artes', 'Garibaldi', 'Guerrero', 'Hidalgo', 'Balderas', 'Salto_del_agua', 'Pino_suarez', 'Candelaria', 'Morelos', 'San_Lazaro'], ['Bellas_artes', 'Garibaldi', 'Guerrero', 'Hidalgo', 'Balderas', 'Salto_del_agua', 'Pino_suarez', 'Candelaria', 'Morelos', 'San_Lazaro']]
#
#
# Modelo objetivo: ['Bellas_artes', 'Garibaldi', 'Guerrero', 'Hidalgo', 'Balderas', 'Salto_del_agua', 'Pino_suarez', 'Candelaria', 'Morelos', 'San_Lazaro']
# Fitness del modelo objetivo: 243.57
#
# El mejor individuo de la útima generación tiene conexiones directas de acuerdo a lo establecido, por lo tanto es posible realizar ese recorrido
#
# Best Individuo: ['Bellas_artes', 'Garibaldi', 'Guerrero', 'Hidalgo', 'Balderas', 'Salto_del_agua', 'Pino_suarez', 'Candelaria', 'Morelos', 'San_Lazaro']
# Fitness: 243.57
# Tiempo de viaje: 24 min
# Sitios visitados: 76

# %%
import matplotlib.pyplot as plt

population = crearPoblacion()#Inicializar una poblacion
evoluciones = 1000
averageFitness = []
print("Poblacion Inicial:\n%s"%(population)) #Se muestra la poblacion inicial
#for i in range(len(population)):
#  print(f"Fitness: {calcularFitness(population[i])} \tIndividuo: {population[i]}")

#Se evoluciona la poblacion
for i in range(evoluciones):
  averageFitness.append(averageFitnessPoblacion(population))
  population = selection_and_reproduction(population)
  #print("\nPoblacion Reproducida:\n%s"%(population)) #Se muestra la poblacion reproducida
  population = mutation(population)
  #print("\nPoblacion Mutada:\n%s"%(population)) #Se muestra la poblacion mutada

print("\nPoblacion Final:\n%s"%(population)) #Se muestra la poblacion evolucionada
#for i in range(len(population)):
#  print(f"Fitness: {calcularFitness(population[i])} \tIndividuo: {population[i]}")
print("\n")

print(f"Modelo objetivo: {modelo}")
print(f"Fitness del modelo objetivo: {calcularFitness(modelo)[0]}\n")

best_individuo = max(population, key=calcularFitness)
if verificar_y_reordenar_individuo(best_individuo,dictionaryConexionStations)[0]:
  print(f"El mejor individuo de la útima generación tiene conexiones directas de acuerdo a lo establecido, por lo tanto es posible realizar ese recorrido\n")
  print(f"Best Individuo: {verificar_y_reordenar_individuo(best_individuo,dictionaryConexionStations)[1]}")
else:
  print(f"El mejor individuo de la útima generación no tiene conexiones directas de acuerdo a lo establecido, por lo tanto no es posible realizar ese recorrido\n")
  print(f"Best individuo: {best_individuo}")

print(f"Fitness: {calcularFitness(best_individuo)[0]}")
print(f"Tiempo de viaje: {calcularFitness(best_individuo)[1]} min")
print(f"Sitios visitados: {calcularFitness(best_individuo)[2]}")

#Grafica del rendimieto en cada iteracion
plt.plot(range(evoluciones), averageFitness)
plt.xlabel("Iteration")
plt.ylabel("Average Fitness")
plt.title("Average Fitness vs Iterations")
plt.show()
# Out:
# Poblacion Inicial:
# [['Atlalilco', 'Candelaria', 'La_Raza', 'El_rosario', 'La_Villa_Basilica', 'Tacuba', 'Morelos', 'Mixcoac', 'Martin_Carrera', 'Hidalgo'], ['La_Villa_Basilica', 'Tacubaya', 'Zapata', 'Garibaldi', 'CentroMedico', 'Guerrero', 'Morelos', 'Consulado', 'Santa_Anita', 'Ermita'], ['Instituto_del_petroleo', 'Deportivo_18_de_Marzo', 'La_Villa_Basilica', 'Morelos', 'Oceania', 'Bellas_artes', 'Ermita', 'Tacuba', 'Guerrero', 'Salto_del_agua'], ['Pino_suarez', 'Hidalgo', 'La_Raza', 'Instituto_del_petroleo', 'Tacuba', 'Chabacano', 'Salto_del_agua', 'El_rosario', 'Consulado', 'Oceania'], ['Martin_Carrera', 'Garibaldi', 'Guerrero', 'Consulado', 'Salto_del_agua', 'Chabacano', 'La_Villa_Basilica', 'San_Lazaro', 'Santa_Anita', 'Bellas_artes'], ['Guerrero', 'Morelos', 'Tacuba', 'Deportivo_18_de_Marzo', 'Chabacano', 'San_Lazaro', 'Zapata', 'Martin_Carrera', 'CentroMedico', 'Bellas_artes'], ['El_rosario', 'Martin_Carrera', 'Bellas_artes', 'Zapata', 'Consulado', 'Universidad', 'Tacubaya', 'Garibaldi', 'Mixcoac', 'Morelos'], ['Pantitlan', 'El_rosario', 'Zapata', 'Hidalgo', 'Universidad', 'Chabacano', 'Tacubaya', 'Guerrero', 'La_Raza', 'Deportivo_18_de_Marzo'], ['Mixcoac', 'CentroMedico', 'Candelaria', 'Pino_suarez', 'Bellas_artes', 'Salto_del_agua', 'Morelos', 'El_rosario', 'Balderas', 'San_Lazaro'], ['Balderas', 'Garibaldi', 'San_Lazaro', 'Guerrero', 'Salto_del_agua', 'Pantitlan', 'Ermita', 'Mixcoac', 'Pino_suarez', 'La_Villa_Basilica'], ['Deportivo_18_de_Marzo', 'Tacuba', 'Hidalgo', 'Salto_del_agua', 'Universidad', 'Chabacano', 'Guerrero', 'Balderas', 'Pantitlan', 'Instituto_del_petroleo'], ['Guerrero', 'Tacuba', 'Universidad', 'Deportivo_18_de_Marzo', 'Instituto_del_petroleo', 'Jamaica', 'Martin_Carrera', 'Ermita', 'Candelaria', 'Salto_del_agua'], ['CentroMedico', 'Ermita', 'Universidad', 'Pino_suarez', 'Guerrero', 'Instituto_del_petroleo', 'Santa_Anita', 'Tacubaya', 'Candelaria', 'Pantitlan'], ['Ermita', 'Candelaria', 'Santa_Anita', 'Tacuba', 'Morelos', 'Mixcoac', 'Tacubaya', 'Bellas_artes', 'Oceania', 'Atlalilco'], ['La_Villa_Basilica', 'Instituto_del_petroleo', 'San_Lazaro', 'Salto_del_agua', 'Candelaria', 'Universidad', 'Hidalgo', 'Chabacano', 'Bellas_artes', 'Morelos'], ['Instituto_del_petroleo', 'Zapata', 'Atlalilco', 'San_Lazaro', 'Candelaria', 'Pantitlan', 'Balderas', 'El_rosario', 'Hidalgo', 'Bellas_artes'], ['Santa_Anita', 'Morelos', 'Zapata', 'Tacubaya', 'Bellas_artes', 'Jamaica', 'Deportivo_18_de_Marzo', 'La_Raza', 'Balderas', 'Ermita'], ['Pantitlan', 'Candelaria', 'Salto_del_agua', 'Pino_suarez', 'Ermita', 'La_Villa_Basilica', 'El_rosario', 'Bellas_artes', 'Balderas', 'Deportivo_18_de_Marzo'], ['Balderas', 'Jamaica', 'Bellas_artes', 'Atlalilco', 'Chabacano', 'Zapata', 'Morelos', 'Candelaria', 'Tacubaya', 'Guerrero'], ['La_Raza', 'Oceania', 'Universidad', 'La_Villa_Basilica', 'Guerrero', 'CentroMedico', 'Martin_Carrera', 'Zapata', 'Mixcoac', 'Pantitlan']]
#
# Poblacion Final:
# [['Bellas_artes', 'Garibaldi', 'Guerrero', 'Hidalgo', 'Balderas', 'Salto_del_agua', 'Pino_suarez', 'Candelaria', 'Morelos', 'San_Lazaro'], ['Pantitlan', 'Garibaldi', 'Guerrero', 'Hidalgo', 'Balderas', 'Salto_del_agua', 'Pino_suarez', 'Candelaria', 'Morelos', 'San_Lazaro'], ['Bellas_artes', 'Garibaldi', 'Guerrero', 'Hidalgo', 'Balderas', 'Salto_del_agua', 'Pino_suarez', 'Candelaria', 'Morelos', 'San_Lazaro'], ['Balderas', 'Garibaldi', 'Guerrero', 'Hidalgo', 'Balderas', 'Salto_del_agua', 'Pino_suarez', 'Candelaria', 'Morelos', 'San_Lazaro'], ['Bellas_artes', 'Garibaldi', 'Guerrero', 'Hidalgo', 'Balderas', 'Salto_del_agua', 'Pino_suarez', 'Candelaria', 'Morelos', 'Oceania'], ['Bellas_artes', 'Garibaldi', 'Guerrero', 'Hidalgo', 'Balderas', 'Salto_del_agua', 'Pino_suarez', 'Candelaria', 'Morelos', 'San_Lazaro'], ['Bellas_artes', 'Garibaldi', 'Guerrero', 'Hidalgo', 'Balderas', 'Salto_del_agua', 'Pino_suarez', 'Garibaldi', 'Morelos', 'San_Lazaro'], ['Bellas_artes', 'Garibaldi', 'Guerrero', 'Hidalgo', 'Balderas', 'Salto_del_agua', 'Pino_suarez', 'Candelaria', 'Morelos', 'San_Lazaro'], ['Bellas_artes', 'Garibaldi', 'Guerrero', 'Hidalgo', 'CentroMedico', 'Salto_del_agua', 'Pino_suarez', 'Candelaria', 'Morelos', 'San_Lazaro'], ['Bellas_artes', 'Garibaldi', 'Guerrero', 'Hidalgo', 'Balderas', 'Salto_del_agua', 'Pino_suarez', 'Candelaria', 'Morelos', 'San_Lazaro'], ['Bellas_artes', 'Garibaldi', 'Guerrero', 'Hidalgo', 'Balderas', 'Salto_del_agua', 'Pino_suarez', 'Candelaria', 'Morelos', 'San_Lazaro'], ['Bellas_artes', 'Bellas_artes', 'Guerrero', 'Hidalgo', 'Balderas', 'Salto_del_agua', 'Pino_suarez', 'Candelaria', 'Morelos', 'San_Lazaro'], ['Bellas_artes', 'Garibaldi', 'Guerrero', 'Hidalgo', 'Balderas', 'La_Raza', 'Pino_suarez', 'Candelaria', 'Morelos', 'San_Lazaro'], ['Bellas_artes', 'Garibaldi', 'Guerrero', 'Hidalgo', 'Balderas', 'Salto_del_agua', 'Pino_suarez', 'Candelaria', 'Morelos', 'San_Lazaro'], ['Bellas_artes', 'Garibaldi', 'Guerrero', 'Hidalgo', 'Balderas', 'Salto_del_agua', 'Pino_suarez', 'Candelaria', 'Morelos', 'Guerrero'], ['Bellas_artes', 'Garibaldi', 'Guerrero', 'Hidalgo', 'Balderas', 'Salto_del_agua', 'Pino_suarez', 'Candelaria', 'Morelos', 'San_Lazaro'], ['Bellas_artes', 'Garibaldi', 'Guerrero', 'Hidalgo', 'Balderas', 'Salto_del_agua', 'Pino_suarez', 'Candelaria', 'Morelos', 'San_Lazaro'], ['Bellas_artes', 'Garibaldi', 'Guerrero', 'Hidalgo', 'Balderas', 'Salto_del_agua', 'Pino_suarez', 'Candelaria', 'Morelos', 'San_Lazaro'], ['Bellas_artes', 'Garibaldi', 'Guerrero', 'Hidalgo', 'Balderas', 'Salto_del_agua', 'Pino_suarez', 'Candelaria', 'Morelos', 'San_Lazaro'], ['Bellas_artes', 'Garibaldi', 'Guerrero', 'Hidalgo', 'Balderas', 'Salto_del_agua', 'Pino_suarez', 'Candelaria', 'Morelos', 'San_Lazaro']]
#
#
# Modelo objetivo: ['Bellas_artes', 'Garibaldi', 'Guerrero', 'Hidalgo', 'Balderas', 'Salto_del_agua', 'Pino_suarez', 'Candelaria', 'Morelos', 'San_Lazaro']
# Fitness del modelo objetivo: 243.57
#
# El mejor individuo de la útima generación tiene conexiones directas de acuerdo a lo establecido, por lo tanto es posible realizar ese recorrido
#
# Best Individuo: ['Bellas_artes', 'Garibaldi', 'Guerrero', 'Hidalgo', 'Balderas', 'Salto_del_agua', 'Pino_suarez', 'Candelaria', 'Morelos', 'San_Lazaro']
# Fitness: 243.57
# Tiempo de viaje: 24 min
# Sitios visitados: 76
